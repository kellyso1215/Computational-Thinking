# %% [markdown]
# <a href="https://colab.research.google.com/github/kellyso1215/Computational-Thinking/blob/main/%E2%80%9C%E6%9C%9F%E6%9C%AB%E2%80%9D%E7%9A%84%E5%89%AF%E6%9C%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
題目=農場 
組員名單=   楊雅婷   洪嫚君   高明倫   黃新雅   鍾艿蓁   廖妤恩   楊采穎    蘇雯雅
組員學號=A109260091 A109260031 A109260003 C105140209 A109260005 A109260067 A109260087  A109260105
組長=廖妤恩 A109260067
分工= 蓋農場:黃新雅 C105140209  蘇雯雅 A109260105
    種作物:高明倫 A109260003  廖妤恩 A109260067
    養動物:楊雅婷 A109260091  洪嫚君 A109260031
    賣作物:鍾艿蓁 A109260005  楊采穎 A109260087

# %%
#開頭
name=input("請輸入姓名")
print("Hi",name,"歡迎來到農場")        
print("我們現在開始來打造你的農場吧!")
#蓋農場
print("請問你要蓋什麼?")
print("你可以選擇:")
print("農田、廠房、房子:")
item=input("你選擇哪個?:")
if item=="農田":
  print("你獲得一塊農田種植農作物")
if item=="廠房":
  print("你獲得廠房加工農作物")
if item=="房子":
  print("你獲得一棟房子")
print("請問你需要工人嗎?")
print("你可以選擇:")
print("農民、生產人員、建築工人:")
item=input("你選擇哪個?:")
if item=="農民":
  print("恭喜強森成為你的新夥伴")
if item=="生產人員":
  print("恭喜露西成為你的新夥伴")
if item=="建築工人":
  print("恭喜喬治成為你的新夥伴")
  #動物
## 農場打工打工
print("歡迎來到農場打工!")
print("********************************************")
print("你現在在動物區。")
print("你可以選擇一種動物餵食:")
print("牛(cattle)、豬(pig)、羊(sheep)、雞(hen):")
item = input("你選擇那個? ") # Question1:想餵什麼動物?
## 開始農場之旅
print("你看到牛想出柵欄。") # Question2:牛想散步
## 農場體驗中選擇
choice1 = input("要讓牛出柵欄嗎? 請輸入 讓 或 不讓: ")
if choice1 == "讓":
   print("你去借鑰匙打開柵欄。")
   print("農場主人阻止你。")
   print("再試一次")
else:
   print("好主意。你聽了農場主人的話聽了農場主人的話。")
   print("你沒打開柵欄。")
   print("你看牛還是想出去!")
   print("你覺得牛可憐")
choice1 = input("要讓牛出柵欄嗎? 請輸入 讓 或 不讓: ")
if choice1 == "讓":
   print("你去借鑰匙打開柵欄。")
   print("農場主人阻止你。")
   print("繼續努力")
else:
   print("好主意。你聽了農場主人的話聽了農場主人的話。")
   print("你沒打開柵欄。")
   print("你看牛還是想出去!")
   print("你覺得牛可憐")
# 這行print("你覺得牛可憐")後,加入以下程式碼:
action = input("要借鑰匙還是回去? 選擇借鑰匙或回去: ")
## 條件選擇與迴圈
while action == "借鑰匙借鑰匙":
  print("主人不借。")
  action = input("要回去或再借一次鑰匙? 選擇回去或借鑰匙: ")
print("你跟牛玩了會兒,又跑去找農場主人。")
print("農場主人終於借你鑰匙。")
print("農場主人請你確認牛隻有沒有回到農舍。")
names = ["Alex", "Bob", "John", "Mary", "Emily"]
for i in names:
    print(i)
print("很高興牛都回到農舍")

#種作物
##播種
print('現在讓我們來種植作物吧!')
print("我們有四種作物依序來種植吧")
作物 = ["種植蓮霧", "種植芒果", "種植柿子","種植草莓"]
for i in 作物: 
   print (i)
print("種子都播種好了，現在要澆水了")
##澆水
num_a=int(input("輸入澆水數量?"))
if num_a>=5:
  print("達成澆水數量，恭喜玩家種植成功")
if num_a<5:
  print("玩家未達成規定澆水量，種植失敗")
print("農田澆水指引結束")
##玩家選擇貨車擺放農田作物(150公斤)

num_a=int(input("輸入擺放的數量?"))
if num_a<=100:
  print("a車貨物成功安置")
if num_a>100:
  print("a車貨物超重，安置失敗")

num_b=int(input("輸入擺放的數量?"))
if num_b<=250:
  print("b車貨物成功安置")
if num_b>250:
  print("b車貨物超重，安置失敗")
print("已幫玩家將農作貨物已放置好在成功的車輛中")




#賣作物
print("歡迎光臨農場，請問您要買什麼作物？")
print("我們有 蓮霧、芒果、柿子、草莓．")
month = input("輸入月份: ")
if month == "12" or month == "1" or month == "2":
   season = "winter"
   print("現在季節是冬天,我們有賣草莓!")
elif month == "3" or month == "4" or month == "5":
     season = "spring"
     print("現在季節是春天,我們有賣蓮霧!")
elif month == "6" or month == "7" or month == "8":
     season = "summer"
     print("現在季節是夏天,我們有賣芒果!")
else:
     season = "autumn"
     print("現在季節是秋天,我們有賣柿子!")
quantity = input("請問數量要多少斤？")
print("好的,為您準備"+quantity+ "斤" + ".")
print("謝謝光臨,歡迎下次光臨．")
# Out:
# 請輸入姓名amy
# Hi amy 歡迎來到農場
# 我們現在開始來打造你的農場吧!
# 請問你要蓋什麼?
# 你可以選擇:
# 農田、廠房、房子:
# 你選擇哪個?:房子
# 你獲得一棟房子
# 請問你需要工人嗎?
# 你可以選擇:
# 農民、生產人員、建築工人:
# 你選擇哪個?:農民
# 恭喜強森成為你的新夥伴
# 歡迎來到農場打工!
# ********************************************
# 你現在在動物區。
# 你可以選擇一種動物餵食:
# 牛(cattle)、豬(pig)、羊(sheep)、雞(hen):
# 你選擇那個? 牛
# 你看到牛想出柵欄。
# 要讓牛出柵欄嗎? 請輸入 讓 或 不讓: 讓
# 你去借鑰匙打開柵欄。
# 農場主人阻止你。
# 再試一次
# 要讓牛出柵欄嗎? 請輸入 讓 或 不讓: 不讓
# 好主意。你聽了農場主人的話聽了農場主人的話。
# 你沒打開柵欄。
# 你看牛還是想出去!
# 你覺得牛可憐
# 要借鑰匙還是回去? 選擇借鑰匙或回去: 回去
# 你跟牛玩了會兒,又跑去找農場主人。
# 農場主人終於借你鑰匙。
# 農場主人請你確認牛隻有沒有回到農舍。
# Alex
# Bob
# John
# Mary
# Emily
# 很高興牛都回到農舍
# 現在讓我們來種植作物吧!
# 我們有四種作物依序來種植吧
# 種植蓮霧
# 種植芒果
# 種植柿子
# 種植草莓
# 種子都播種好了，現在要澆水了
# 輸入澆水數量?50
# 達成澆水數量，恭喜玩家種植成功
# 農田澆水指引結束
# 輸入擺放的數量?150
# a車貨物超重，安置失敗
# 輸入擺放的數量?150
# b車貨物成功安置
# 已幫玩家將農作貨物已放置好在成功的車輛中
# 歡迎光臨農場，請問您要買什麼作物？
# 我們有 蓮霧、芒果、柿子、草莓．
# 輸入月份: 5
# 現在季節是春天,我們有賣蓮霧!
# 請問數量要多少斤？20
# 好的,為您準備20斤.
# 謝謝光臨,歡迎下次光臨．
